# %%
# Import dependencies and cofig file.
from config import g_key
from config import gkey
import pandas as pd
import requests

# %%
import gmaps
# Configure gmaps
gmaps.configure(api_key=g_key)

# %%
df = pd.read_csv('df_37.csv')
df
# Out:
#     Unnamed: 0                                            Company  \
# 0            0                      4ROSES - Four Roses Gift Shop
# 1            4               BARHSE - Barrel House Distilling Co.
# 2            9                DUELGR - Dueling Grounds Distillery
# 3           12                               HEAVEN - Heaven Hill
# 4           22                      MBROLL - MB Roland Distillery
# 5           23                      MICHTE - Michter's Distillery
# 6           24         MMGIFT - Maker's Mark Distillery-Gift Shop
# 7           26                                 OLDPOG - Old Pogue
# 8           34            WILDTK - Wild Turkey Distillery Gift St
# 9           35                        WILLET - Willett Distillery
# 10          36               WOODFD - Woodford Reserve Distillery
# 11          40                   ANGELS - Angel's Envy Distillery
# 12          43                 BARDBN - Bardstown Bourbon Company
# ...

# %%
df.drop(df.filter(regex="Unname"), axis=1, inplace=True)

# %%
df.columns.to_list()

# %%
df.head()
# Out:
#                                 Company                 Address          City  \
# 0         4ROSES - Four Roses Gift Shop      1224 Bonds Mill Rd  Lawrenceburg
# 1  BARHSE - Barrel House Distilling Co.  1200 Manchester Street     Lexington
# 2   DUELGR - Dueling Grounds Distillery   545 George Taylor Rd.      Franklin
# 3                  HEAVEN - Heaven Hill        1064 Loretto Rd.     Bardstown
# 4         MBROLL - MB Roland Distillery     137 Barkers Mill Rd      Pembroke
#
#   State    Zip        Lat       Long  \
# 0    KY  40342  37.973573 -84.897551
# 1    KY  40504  38.056434 -84.519034
# 2    KY  42134  37.171694 -86.594397
# 3    KY  40004  38.014017 -85.470789
# 4    KY  42266  36.698430 -87.391661
#
#                                       Nearest Kroger
# 0  1300 Anderson Crossing Dr, Lawrenceburg, KY 40342
# 1                704 Euclid Ave, Lexington, KY 40502
# 2       2945 Scottsville Rd, Bowling Green, KY 42104
# 3         102 W John Rowan Blvd, Bardstown, KY 40004
# ...

# %%
# 2. Using the template add the city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Distillery Name</dt><dd>{Company}</dd>
<dt>Address</dt><dd>{Address}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>State</dt><dd>{State}</dd>
<dt>Zip</dt><dd>{Zip}</dd>
<dt>Nearest Kroger</dt><dd>{Nearest Kroger}</dd>
</dl>
"""

# 3a. Get the data from each row and add it to the formatting template and store the data in a list.
distillery_info = [info_box_template.format(**row) for index, row in df.iterrows()]

# 3b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = df[["Lat", "Long"]]

# %%
# 4a. Add a marker layer for each city to the map.
fig = gmaps.figure(center=(38.25, -85), zoom_level=7.25)
marker_layer = gmaps.marker_layer(locations, info_box_content=distillery_info)
fig.add_layer(marker_layer)
# 4b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
